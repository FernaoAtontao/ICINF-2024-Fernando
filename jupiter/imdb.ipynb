# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataIMDB = pd.read_csv("essets/data/datanueva.csv", index_col="ID")
dataIMDB.head()
# Out:
#                 Series_Title  \
# ID
# 1   The Shawshank Redemption
# 2              The Godfather
# 3            The Dark Knight
# 4     The Godfather: Part II
# 5               12 Angry Men
#
#                                           Poster_Link Released_Year  \
# ID
# 1   https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 2   https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 3   https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 4   https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# 5   https://m.media-amazon.com/images/M/MV5BMWU4N2...          1957
#
#    Certificate  Runtime                 Genre  IMDB_Rating  \
# ID
# 1            A  142 min                 Drama          9.3
# 2            A  175 min          Crime, Drama          9.2
# 3           UA  152 min  Action, Crime, Drama          9.0
# 4            A  202 min          Crime, Drama          9.0
# 5            U   96 min          Crime, Drama          9.0
# ...

# %% [markdown]
# <h4><b>DIMENSIÓN DEL DATASET</b></h4>

# %%
print(f'Cantidad de Filas y Columnas del Dataset: {dataIMDB.shape}')
# Out:
# Cantidad de Filas y Columnas del Dataset: (1000, 16)

# %% [markdown]
# <h4><b>IDENTIFICANDO LAS COLUMNAS CON DATOS NULOS</b></h4>

# %%
dataIMDB.isnull().any()
# Out:
# Series_Title     False
# Poster_Link      False
# Released_Year    False
# Certificate       True
# Runtime          False
# Genre            False
# IMDB_Rating      False
# Overview         False
# Meta_score        True
# Director         False
# Star1            False
# Star2            False
# Star3            False
# Star4            False
# No_of_Votes      False
# Gross             True
# dtype: bool

# %% [markdown]
# <h4><b>IDENTIFICANDO LAS FILAS EN ESPECIFICAS CON DATOS NULOS</b></h4>

# %%
# Filtrar las filas que contienen valores nulos
filas_nulas = dataIMDB[dataIMDB.isnull().any(axis=1)]

filas_nulas
# Out:
#                 Series_Title  \
# ID
# 19                  Hamilton
# 21           Soorarai Pottru
# 31                   Seppuku
# 33     It's a Wonderful Life
# 47            Hotaru no haka
# ...                      ...
# 994                   Blowup
# 996   Breakfast at Tiffany's
# 997                    Giant
# 999                 Lifeboat
# 1000            The 39 Steps
#
#                                             Poster_Link Released_Year  \
# ID
# 19    https://m.media-amazon.com/images/M/MV5BNjViNW...          2020
# 21    https://m.media-amazon.com/images/M/MV5BOTc2ZT...          2020
# 31    https://m.media-amazon.com/images/M/MV5BYjBmYT...          1962
# 33    https://m.media-amazon.com/images/M/MV5BZjc4ND...          1946
# 47    https://m.media-amazon.com/images/M/MV5BZmY2Nj...          1988
# ...                                                 ...           ...
# 994   https://m.media-amazon.com/images/M/MV5BYTE4YW...          1966
# ...

# %% [markdown]
# <h4><b>IDENTIFICANDO LAS FILAS EN ESPECIFICAS CON DATOS NULOS DE LA COLUMNA META SCORE</b></h4>

# %%
filas_nulas_metascore = dataIMDB[dataIMDB['Meta_score'].isnull()]
filas_nulas_metascore
# Out:
#                       Series_Title  \
# ID
# 21                 Soorarai Pottru
# 55       Ayla: The Daughter of War
# 56                    Vikram Vedha
# 58                          Dangal
# 66                Taare Zameen Par
# ..                             ...
# 873  The Day the Earth Stood Still
# 875                          Gilda
# 900                      El cuerpo
# 910                      Celda 211
# 914                      Die Welle
#
#                                            Poster_Link Released_Year  \
# ID
# 21   https://m.media-amazon.com/images/M/MV5BOTc2ZT...          2020
# 55   https://m.media-amazon.com/images/M/MV5BNWJhMD...          2017
# 56   https://m.media-amazon.com/images/M/MV5BY2FiMT...          2017
# 58   https://m.media-amazon.com/images/M/MV5BMTQ4Mz...          2016
# 66   https://m.media-amazon.com/images/M/MV5BMDhjZW...          2007
# ..                                                 ...           ...
# ...

# %% [markdown]
# <h4><b>MOSTRAR LA CANTIDAD DE FILAS NULAS DE LAS COLUMNAS CERTIFICATE y METASCORE</b></h4>

# %%
cant_f_nulascertificate = dataIMDB['Certificate'].isnull().sum()
cant_f_nulasscore = dataIMDB['Meta_score'].isnull().sum()
print(f'La cantidad de filas nulas de la columna Certificate es: {cant_f_nulascertificate}')
print(f'La cantidad de filas nulas de la columna Certificate es: {cant_f_nulasscore}')
# Out:
# La cantidad de filas nulas de la columna Certificate es: 101
# La cantidad de filas nulas de la columna Certificate es: 157

# %% [markdown]
# <h4><b>ELIMINANDO NULOS DE LAS COLUMNAS CERTIFICATE y META SCORE</b></h4>

# %%
df_sin_nulos = dataIMDB.dropna(subset=['Certificate', 'Meta_score'])
df_sin_nulos.count()
# Out:
# Series_Title     787
# Poster_Link      787
# Released_Year    787
# Certificate      787
# Runtime          787
# Genre            787
# IMDB_Rating      787
# Overview         787
# Meta_score       787
# Director         787
# Star1            787
# Star2            787
# Star3            787
# Star4            787
# No_of_Votes      787
# Gross            714
# dtype: int64

# %%
df_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 787 entries, 1 to 998
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   787 non-null    object
#  1   Poster_Link    787 non-null    object
#  2   Released_Year  787 non-null    object
#  3   Certificate    787 non-null    object
#  4   Runtime        787 non-null    object
#  5   Genre          787 non-null    object
#  6   IMDB_Rating    787 non-null    float64
#  7   Overview       787 non-null    object
#  8   Meta_score     787 non-null    float64
#  9   Director       787 non-null    object
#  10  Star1          787 non-null    object
#  11  Star2          787 non-null    object
#  12  Star3          787 non-null    object
#  13  Star4          787 non-null    object
#  14  No_of_Votes    787 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 104.5+ KB

# %%
df_sin_nulos.head()
# Out:
#                 Series_Title  \
# ID
# 1   The Shawshank Redemption
# 2              The Godfather
# 3            The Dark Knight
# 4     The Godfather: Part II
# 5               12 Angry Men
#
#                                           Poster_Link Released_Year  \
# ID
# 1   https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 2   https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 3   https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 4   https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# 5   https://m.media-amazon.com/images/M/MV5BMWU4N2...          1957
#
#    Certificate  Runtime                 Genre  IMDB_Rating  \
# ID
# 1            A  142 min                 Drama          9.3
# 2            A  175 min          Crime, Drama          9.2
# 3           UA  152 min  Action, Crime, Drama          9.0
# 4            A  202 min          Crime, Drama          9.0
# 5            U   96 min          Crime, Drama          9.0
# ...

# %%
promedio_por_categoria = df_sin_nulos.groupby('Director')['Meta_score'].mean()
promedio_por_categoria.head(10)
# Out:
# Director
# Aaron Sorkin             77.000000
# Abdellatif Kechiche      89.000000
# Abhishek Kapoor          40.000000
# Adam McKay               81.000000
# Akira Kurosawa           92.666667
# Alan J. Pakula           84.000000
# Alan Parker              57.000000
# Alejandro Amenábar       74.000000
# Alejandro G. Iñárritu    79.000000
# Alejandro Jodorowsky     76.000000
# Name: Meta_score, dtype: float64

# %% [markdown]
# <h4><b>FUNCIÓN PARA VERIFICAR SI EL GENERO WAR ESTÁ PRESENTE EN LA LISTA Y GENERANDO UN NUEVO DATAFRAME</b></h4>

# %%
def filtro_war(genres):
    return 'War' in genres

#Aplica el filtro utilizando apply
datosWAR = df_sin_nulos[df_sin_nulos['Genre'].apply(filtro_war)]

#Muestra el dataset solamente incluyendo la columnas Titulo y Ranting
peliswar = datosWAR[['Series_Title', 'IMDB_Rating', 'Meta_score']]
peliswar
# Out:
#                        Series_Title  IMDB_Rating  Meta_score
# ID
# 25              Saving Private Ryan          8.6        91.0
# 47                   Hotaru no haka          8.5        94.0
# 51                       Casablanca          8.5       100.0
# 75                   Apocalypse Now          8.4        94.0
# 81                   Paths of Glory          8.4        90.0
# 85                             1917          8.3        78.0
# 91                        Incendies          8.3        80.0
# 94             Inglourious Basterds          8.3        69.0
# 105               Full Metal Jacket          8.3        76.0
# 151                 Pan's Labyrinth          8.2        98.0
# 173                             Ran          8.2        96.0
# 183           Judgment at Nuremberg          8.2        60.0
# 193              To Be or Not to Be          8.2        86.0
# 237           Taegukgi hwinalrimyeo          8.1        64.0
# ...

# %% [markdown]
# <h4><b>GENERANDO UN GRÁFICO EN BARRA DE LAS PRIMERAS 10 PELICULAS DE GUERRA</b></h4>

# %% [markdown]
# <h4><b>COMPARANDO EL IMDB RATING CON EL META SCORE</b></h4>

# %%
df_war = peliswar.head(10)
df_war.set_index('Series_Title', inplace=True)


ax = df_war.plot(kind='bar', figsize=(10, 6))

for i, rating in enumerate(df_war['IMDB_Rating']):
    ax.annotate(str(rating), xy=(i, rating), ha='center', va='bottom')

for i, score in enumerate(df_war['Meta_score']):
    ax.annotate(str(score), xy=(i, score), ha='center', va='bottom')

plt.show()
